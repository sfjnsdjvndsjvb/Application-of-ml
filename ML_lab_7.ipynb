# %%
import pandas as pd
data = pd.read_csv("Indian Liver Patient Dataset (ILPD).csv")
data
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0     65  Female            0.7               0.1           187       16
# 1     62    Male           10.9               5.5           699       64
# 2     62    Male            7.3               4.1           490       60
# 3     58    Male            1.0               0.4           182       14
# 4     72    Male            3.9               2.0           195       27
# ..   ...     ...            ...               ...           ...      ...
# 578   60    Male            0.5               0.1           500       20
# 579   40    Male            0.6               0.1            98       35
# 580   52    Male            0.8               0.2           245       48
# 581   31    Male            1.3               0.5           184       29
# 582   38    Male            1.0               0.3           216       21
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               583 non-null    int64
#  1   gender            583 non-null    object
#  2   tot_bilirubin     583 non-null    float64
#  3   direct_bilirubin  583 non-null    float64
#  4   tot_proteins      583 non-null    int64
#  5   albumin           583 non-null    int64
#  6   ag_ratio          583 non-null    int64
#  7   sgpt              583 non-null    float64
#  8   sgot              583 non-null    float64
#  9   alkphos           579 non-null    float64
#  10  is_patient        583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
data.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             4
# is_patient          0
# dtype: int64

# %%
data = data.dropna(axis = 1)
data.drop_duplicates(inplace=True)
data
# Out:
# <ipython-input-4-211d9609678c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace=True)
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0     65  Female            0.7               0.1           187       16
# 1     62    Male           10.9               5.5           699       64
# 2     62    Male            7.3               4.1           490       60
# 3     58    Male            1.0               0.4           182       14
# 4     72    Male            3.9               2.0           195       27
# ..   ...     ...            ...               ...           ...      ...
# 578   60    Male            0.5               0.1           500       20
# 579   40    Male            0.6               0.1            98       35
# ...

# %%
data.replace({'gender': {'Male':0, 'Female':1}}, inplace = True)
abs(data.corr()['is_patient']).sort_values(ascending=False)
# Out:
# <ipython-input-5-c758e9842ea1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace({'gender': {'Male':0, 'Female':1}}, inplace = True)
# is_patient          1.000000
# direct_bilirubin    0.250666
# tot_bilirubin       0.224430
# tot_proteins        0.187560
# sgot                0.166835
# albumin             0.161917
# ag_ratio            0.151101
# age                 0.138093
# gender              0.078501
# sgpt                0.037794
# Name: is_patient, dtype: float64

# %%
data = data.drop(columns = ['gender','sgpt'])
data
# Out:
#      age  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  ag_ratio  \
# 0     65            0.7               0.1           187       16        18
# 1     62           10.9               5.5           699       64       100
# 2     62            7.3               4.1           490       60        68
# 3     58            1.0               0.4           182       14        20
# 4     72            3.9               2.0           195       27        59
# ..   ...            ...               ...           ...      ...       ...
# 578   60            0.5               0.1           500       20        34
# 579   40            0.6               0.1            98       35        31
# 580   52            0.8               0.2           245       48        49
# 581   31            1.3               0.5           184       29        32
# 582   38            1.0               0.3           216       21        24
#
#      sgot  is_patient
# 0     3.3           1
# ...

# %%
X = data.drop(columns = ['is_patient']).values
Y = data['is_patient']

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

from sklearn.model_selection import train_test_split
XTrain, XTest, YTrain, YTest = train_test_split(X,Y, test_size= 0.20, random_state= 2)

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors= 4)
model.fit(XTrain, YTrain)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
YPred1 = model.predict(XTest)

from sklearn.metrics import accuracy_score
acc = accuracy_score(YTest,YPred1)
print("Accuracy Score of KNN Model :- ", acc*100)
# Out:
# Accuracy Score of KNN Model :-  68.42105263157895

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(XTrain, YTrain)
# Out:
# LogisticRegression()

# %%
YPred2 = log.predict(XTest)

from sklearn.metrics import accuracy_score
acc = accuracy_score(YTest,YPred2)
print("Accuracy Score of Logistic Regression :- ", acc*100)
# Out:
# Accuracy Score of Logistic Regression :-  71.05263157894737
